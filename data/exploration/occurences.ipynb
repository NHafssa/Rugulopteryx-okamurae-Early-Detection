# %% [markdown]
# # Observing Occurrences Data

# %%
# IMPORTS
import numpy as np
import pandas as pd

# %%
# DATA PATHS
path_root = "../db/occurrence/processed"

# %%
# LOAD PRESENCE / ABSENCE DATA FROM GBIF
data_present = pd.read_csv(f"{path_root}/gbif_occurrences_present.csv")
data_absent = pd.read_csv(f"{path_root}/gbif_occurrences_absent.csv")

# %%
# What years should data be fetched for?
years = list(set(data_absent.year.unique().tolist() + 
                 data_present.year.unique().tolist()))
print("Data should be fetched for years:", years)
# Out:
# Data should be fetched for years: [1938.0, 1945.0, 1954.0, 1962.0, 1964.0, 1970.0, 1971.0, 1972.0, 1980.0, 1982.0, 1985.0, 1986.0, 1987.0, 1988.0, 1989.0, 1990.0, 1992.0, 1993.0, 1994.0, 1998.0, 1999.0, 2001.0, 2002.0, 2003.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0, 2011.0, 2012.0, 2013.0, 2014.0, 2015.0, 2016.0, 2017.0, 2018.0, 2019.0, 2020.0, 2021.0, 2022.0, 2023.0, 2024.0, 2025.0]
